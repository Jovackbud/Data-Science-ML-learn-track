# %%
import pandas as pd

# %%
import numpy as np

# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
df1 = pd.read_csv('df1', index_col=0)

# %%
df2 = pd.read_csv('df2')

# %%
df3 = pd.read_csv('df3')

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1['A'].hist()
# Out:
# <AxesSubplot:>

# %%
df1['A'].hist(bins=30)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df2.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.hist(bins=30, edgecolor='white')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['A'].plot.line(x=df1.index, y='B')
# Out:
# <AxesSubplot:>

# %%
df1['A'].plot.line(x=df1.index, y='B', figsize=(12,7), lw=1)
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x='A', y='B')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c = 'C')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', c = 'C', cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.scatter(x='A', y='B', s=df1['C']*30)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\matplotlib\collections.py:922: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
df1.plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])

# %%
df.plot.hexbin(x='a', y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a', y='b', gridsize = 20)
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df.plot.hexbin(x='a', y='b', gridsize = 40, cmap='coolwarm')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df2['a'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df2.plot.density()
# Out:
# <AxesSubplot:ylabel='Density'>
